# %%
# %pip install torch==1.12.1+cu116 --extra-index-url https://download.pytorch.org/whl/cu116
# %pip install torchvision==0.13.1+cu116 --extra-index-url https://download.pytorch.org/whl/cu116
# %pip install torchaudio==0.12.1+cu116 --extra-index-url https://download.pytorch.org/whl/cu116
# %pip install -r environment/p2p_requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu116
# Requirement already satisfied: torch==1.12.1+cu116 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (1.12.1+cu116)
# Requirement already satisfied: typing-extensions in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from torch==1.12.1+cu116) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu116
# Requirement already satisfied: torchvision==0.13.1+cu116 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (0.13.1+cu116)
# Requirement already satisfied: typing-extensions in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from torchvision==0.13.1+cu116) (4.15.0)
# Requirement already satisfied: numpy in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from torchvision==0.13.1+cu116) (1.23.5)
# Requirement already satisfied: requests in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from torchvision==0.13.1+cu116) (2.32.5)
# Requirement already satisfied: torch==1.12.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from torchvision==0.13.1+cu116) (1.12.1+cu116)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from torchvision==0.13.1+cu116) (11.3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from requests->torchvision==0.13.1+cu116) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from requests->torchvision==0.13.1+cu116) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from requests->torchvision==0.13.1+cu116) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from requests->torchvision==0.13.1+cu116) (2025.10.5)
# Note: you may need to restart the kernel to use updated packages.
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu116
# Requirement already satisfied: torchaudio==0.12.1+cu116 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (0.12.1+cu116)
# Requirement already satisfied: torch==1.12.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from torchaudio==0.12.1+cu116) (1.12.1+cu116)
# Requirement already satisfied: typing-extensions in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from torch==1.12.1->torchaudio==0.12.1+cu116) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting git+https://github.com/openai/CLIP.git (from -r environment/p2p_requirements.txt (line 13))
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-_qe2_y32
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-_qe2_y32
#
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy==1.23.5 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from -r environment/p2p_requirements.txt (line 1)) (1.23.5)
# Requirement already satisfied: huggingface-hub==0.16.4 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from -r environment/p2p_requirements.txt (line 2)) (0.16.4)
# Requirement already satisfied: tokenizers==0.13.3 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from -r environment/p2p_requirements.txt (line 3)) (0.13.3)
# Requirement already satisfied: transformers==4.26.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from -r environment/p2p_requirements.txt (line 4)) (4.26.0)
# Requirement already satisfied: diffusers==0.10.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from -r environment/p2p_requirements.txt (line 5)) (0.10.0)
# Requirement already satisfied: accelerate==0.16.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from -r environment/p2p_requirements.txt (line 6)) (0.16.0)
# Requirement already satisfied: ftfy in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from -r environment/p2p_requirements.txt (line 7)) (6.3.1)
# Requirement already satisfied: opencv-python==4.6.0.66 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from -r environment/p2p_requirements.txt (line 8)) (4.6.0.66)
# Requirement already satisfied: ipywidgets in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from -r environment/p2p_requirements.txt (line 9)) (8.1.8)
# Requirement already satisfied: matplotlib in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from -r environment/p2p_requirements.txt (line 10)) (3.9.4)
# Requirement already satisfied: regex in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from -r environment/p2p_requirements.txt (line 11)) (2025.11.3)
# Requirement already satisfied: tqdm in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from -r environment/p2p_requirements.txt (line 12)) (4.67.1)
# Requirement already satisfied: torchmetrics==0.11.4 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from -r environment/p2p_requirements.txt (line 14)) (0.11.4)
# Requirement already satisfied: lpips==0.1.4 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from -r environment/p2p_requirements.txt (line 15)) (0.1.4)
# Requirement already satisfied: packaging in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from clip==1.0->-r environment/p2p_requirements.txt (line 13)) (25.0)
# Requirement already satisfied: torch in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from clip==1.0->-r environment/p2p_requirements.txt (line 13)) (1.12.1+cu116)
# Requirement already satisfied: torchvision in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from clip==1.0->-r environment/p2p_requirements.txt (line 13)) (0.13.1+cu116)
# Requirement already satisfied: filelock in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from huggingface-hub==0.16.4->-r environment/p2p_requirements.txt (line 2)) (3.19.1)
# Requirement already satisfied: fsspec in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from huggingface-hub==0.16.4->-r environment/p2p_requirements.txt (line 2)) (2025.10.0)
# Requirement already satisfied: requests in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from huggingface-hub==0.16.4->-r environment/p2p_requirements.txt (line 2)) (2.32.5)
# Requirement already satisfied: pyyaml>=5.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from huggingface-hub==0.16.4->-r environment/p2p_requirements.txt (line 2)) (6.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from huggingface-hub==0.16.4->-r environment/p2p_requirements.txt (line 2)) (4.15.0)
# Requirement already satisfied: importlib-metadata in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from diffusers==0.10.0->-r environment/p2p_requirements.txt (line 5)) (8.7.0)
# Requirement already satisfied: Pillow in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from diffusers==0.10.0->-r environment/p2p_requirements.txt (line 5)) (11.3.0)
# Requirement already satisfied: psutil in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from accelerate==0.16.0->-r environment/p2p_requirements.txt (line 6)) (7.0.0)
# Requirement already satisfied: scipy>=1.0.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from lpips==0.1.4->-r environment/p2p_requirements.txt (line 15)) (1.13.1)
# Requirement already satisfied: wcwidth in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from ftfy->-r environment/p2p_requirements.txt (line 7)) (0.2.13)
# Requirement already satisfied: comm>=0.1.3 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from ipywidgets->-r environment/p2p_requirements.txt (line 9)) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from ipywidgets->-r environment/p2p_requirements.txt (line 9)) (8.18.1)
# Requirement already satisfied: traitlets>=4.3.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from ipywidgets->-r environment/p2p_requirements.txt (line 9)) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from ipywidgets->-r environment/p2p_requirements.txt (line 9)) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from ipywidgets->-r environment/p2p_requirements.txt (line 9)) (3.0.16)
# Requirement already satisfied: contourpy>=1.0.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from matplotlib->-r environment/p2p_requirements.txt (line 10)) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from matplotlib->-r environment/p2p_requirements.txt (line 10)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from matplotlib->-r environment/p2p_requirements.txt (line 10)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from matplotlib->-r environment/p2p_requirements.txt (line 10)) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from matplotlib->-r environment/p2p_requirements.txt (line 10)) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from matplotlib->-r environment/p2p_requirements.txt (line 10)) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from matplotlib->-r environment/p2p_requirements.txt (line 10)) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->-r environment/p2p_requirements.txt (line 10)) (3.23.0)
# Requirement already satisfied: decorator in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->-r environment/p2p_requirements.txt (line 9)) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->-r environment/p2p_requirements.txt (line 9)) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->-r environment/p2p_requirements.txt (line 9)) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->-r environment/p2p_requirements.txt (line 9)) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->-r environment/p2p_requirements.txt (line 9)) (2.19.2)
# Requirement already satisfied: stack-data in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->-r environment/p2p_requirements.txt (line 9)) (0.6.3)
# Requirement already satisfied: exceptiongroup in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->-r environment/p2p_requirements.txt (line 9)) (1.3.0)
# Requirement already satisfied: pexpect>4.3 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->-r environment/p2p_requirements.txt (line 9)) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->-r environment/p2p_requirements.txt (line 9)) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets->-r environment/p2p_requirements.txt (line 9)) (0.7.0)
# Requirement already satisfied: six>=1.5 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->-r environment/p2p_requirements.txt (line 10)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from requests->huggingface-hub==0.16.4->-r environment/p2p_requirements.txt (line 2)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from requests->huggingface-hub==0.16.4->-r environment/p2p_requirements.txt (line 2)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from requests->huggingface-hub==0.16.4->-r environment/p2p_requirements.txt (line 2)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from requests->huggingface-hub==0.16.4->-r environment/p2p_requirements.txt (line 2)) (2025.10.5)
# Requirement already satisfied: executing>=1.2.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->-r environment/p2p_requirements.txt (line 9)) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->-r environment/p2p_requirements.txt (line 9)) (3.0.0)
# Requirement already satisfied: pure_eval in /system/conda/miniconda3/envs/cloudspace/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->-r environment/p2p_requirements.txt (line 9)) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
print(torch.__version__)
# Out:
# 1.12.1

# %%
try:
    import peft
    print(f"✅ peft版本: {peft.__version__}")
except ImportError:
    print("❌ peft不可用")
